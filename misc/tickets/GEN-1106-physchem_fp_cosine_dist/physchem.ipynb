# %% [markdown]
# # Phys. Chem. FP

# %%
# setup
import sys
PATH_TO_TOP = "/genra"
if PATH_TO_TOP not in sys.path:
    sys.path.append(PATH_TO_TOP)
import os
os.chdir(PATH_TO_TOP)
from IPython.display import JSON

# %%
from genraweb.resources import DB
q = {"dsstox_cid": "DTXCID30182"}
p = {"_id": 0}
fp = DB.physchem_fp.find_one(q)["phch"]
bpa_v = list(fp['ds'].values())
print(fp)
bpa_v
# Out:
# 1026-181814:db_connection.py:80 mongodb://user:pword@ccte-mongodb-dev.epa.gov:27017/genra?serverSelectionTimeoutMS=5000&authSource=admin
# 1026-181814:db_connection.py:226 Connect '' OK: URI connector
# 1026-181814:db_connection.py:80 mongodb://user:pword@ccte-mongodb-dev.epa.gov:27017/genra?serverSelectionTimeoutMS=5000&authSource=admin
# {'ds': {'mass': 228.291, 'HBD': 2, 'HBA': 2, 'logKow': 3.32044}, 'n': 4}
# [228.291, 2, 2, 3.32044]

# %%
DB.physprop.find_one(q)['predicted_props']['OPERA_LogP']
# Out:
# [3.32044]

# %%
[(k, v) for k, v in DB.compounds.find_one(q).items() if k in ('mol_weight', 'HBA', 'HBD')]
# Out:
# [('mol_weight', 228.291), ('HBA', 2), ('HBD', 2)]

# %%
qC = {"dsstox_cid": "DTXCID407391"}
fp = DB.physchem_fp.find_one(qC)["phch"]
C_v = list(fp['ds'].values())
print(fp)
C_v
# Out:
# {'ds': {'mass': 12.011, 'HBD': 0, 'HBA': 0, 'logKow': 1.0888}, 'n': 4}
# [12.011, 0, 0, 1.0888]

# %%
from scipy.spatial.distance import cosine
cd = cosine(bpa_v, C_v)
print(bpa_v, C_v, cd, (cd+1)/2)
# Out:
# [228.291, 2, 2, 3.32044] [12.011, 0, 0, 1.0888] 0.002952450102236104 0.501476225051118

# %%
JSON(DB.fp_info.find_one(q)['chm_phch'])

# %%
next = [226.7,2,2,3.25623]
cd = cosine(bpa_v, next)
print(bpa_v, next, cd, (cd+1)/2)
# Out:
# [228.291, 2, 2, 3.32044] [226.7, 2, 2, 3.25623] 2.0181437410116132e-08 0.5000000100907187

# %%
next = [114.188,1,1,1.68202]
cd = cosine(bpa_v, next)
print(bpa_v, next, cd, (cd+1)/2)
# Out:
# [228.291, 2, 2, 3.32044] [114.188, 1, 1, 1.68202] 1.7205855407098625e-08 0.5000000086029277

# %%
next = [114.188,1,1,1.68202]
cd = cosine([443.713,4,4,6.54636], next)
print(cd, (cd+1)/2)
# Out:
# 6.646317141090208e-08 0.5000000332315857

# %%
cd = cosine([443.713,4,4,6.54636], C_v)
print(C_v, cd, (cd+1)/2)
# Out:
# [12.011, 0, 0, 1.0888] 0.002941151711925216 0.5014705758559626
